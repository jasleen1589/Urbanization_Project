# %%
#dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %% [markdown]
# # cleaning crime rate starts here:

# %%
#setting file path and reading in the crime file
file = Path("../Resources/cleaner_crime_rate.csv")
df = pd.read_csv(file)
df.tail()
# Out:
#       County Population Violent  Murder   Rape  Robbery  Aggrevated assault  \
# 54  Tuolumne     54,532   357.6     3.7  124.7     23.8               205.4
# 55   Ventura    846,050   216.3     2.8   27.4     62.3               123.8
# 56      Yolo    220,896   288.4     2.7   39.4     79.7               166.6
# 57      Yuba     77,342   421.5     9.1   53.0     78.9               280.6
# 58       NaN        NaN     NaN     NaN    NaN      NaN                 NaN
#
#     Property Burglary  Vehicle theft Larceny theft
# 54  1,969.50    687.7          185.2      1,096.60
# 55  1,493.30      230          145.9      1,117.40
# 56  3,007.80    418.7          265.7      2,323.30
# 57  2,384.20    523.6          614.2      1,246.40
# 58       NaN      NaN            NaN           NaN

# %%
#pulling only the columns we want to look at
#note: violent includes murder, rape, robbery, aggevated assault and property includes burglary, vehicle theft,
#and larceny theft
minimized_df = df[["County","Population","Violent", "Property"]]
minimized_df.head()
# Out:
#       County Population   Violent  Property
# 0    Alameda  1,664,783     584.7  4,008.40
# 1     Alpine      1,149  1,131.40  2,785.00
# 2     Amador     37,820     290.9  1,771.50
# 3      Butte    221,521     462.3  2,402.50
# 4  Calaveras     45,085     321.6  1,858.70

# %%
#checking the data types
minimized_df.dtypes
# Out:
# County        object
# Population    object
# Violent       object
# Property      object
# dtype: object

# %%
#removing the comma mapping for the numbers so that the values are floats
minimized_df.replace(',', '', regex=True, inplace=True)
minimized_df.head()
# Out:
# /var/folders/3_/pnzxh0yn5lqbg2gh85_bx9gc0000gn/T/ipykernel_7818/483355146.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minimized_df.replace(',', '', regex=True, inplace=True)
#       County Population  Violent Property
# 0    Alameda    1664783    584.7  4008.40
# 1     Alpine       1149  1131.40  2785.00
# 2     Amador      37820    290.9  1771.50
# 3      Butte     221521    462.3  2402.50
# 4  Calaveras      45085    321.6  1858.70

# %%
#changing the data types of the numeric columns
minimized_df[["Population", "Violent", "Property"]] = minimized_df[["Population", "Violent", "Property"]].astype({"Population": float, "Violent": float, "Property": float})
# Out:
# /var/folders/3_/pnzxh0yn5lqbg2gh85_bx9gc0000gn/T/ipykernel_7818/3034067415.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minimized_df[["Population", "Violent", "Property"]] = minimized_df[["Population", "Violent", "Property"]].astype({"Population": float, "Violent": float, "Property": float})

# %%
#making sure the data types were changed correctly 
minimized_df.dtypes
# Out:
# County         object
# Population    float64
# Violent       float64
# Property      float64
# dtype: object

# %%
#sorted ascending so that it'll comply with plotly standards
sorted_df = minimized_df.sort_values("Population")
sorted_df.head()
# Out:
#      County  Population  Violent  Property
# 1    Alpine      1149.0   1131.4    2785.0
# 45   Sierra      3210.0     31.2     965.7
# 24    Modoc      9637.0    446.2     684.9
# 25     Mono     13517.0    495.7    1383.4
# 52  Trinity     13637.0    447.3    1737.9

# %%
reset_crime_index = sorted_df.reset_index(drop = True)
reset_crime_index
# Out:
#              County  Population  Violent  Property
# 0            Alpine      1149.0   1131.4    2785.0
# 1            Sierra      3210.0     31.2     965.7
# 2             Modoc      9637.0    446.2     684.9
# 3              Mono     13517.0    495.7    1383.4
# 4           Trinity     13637.0    447.3    1737.9
# 5          Mariposa     18066.0    437.3    1007.4
# 6            Plumas     18242.0    701.7    1721.3
# 7              Inyo     18572.0    506.1    2116.1
# 8            Colusa     21990.0    263.8    1578.0
# 9         Del Norte     27127.0    401.8    2963.8
# 10            Glenn     28695.0    317.1    1833.1
# 11           Lassen     29173.0    939.2    1436.3
# 12           Amador     37820.0    290.9    1771.5
# 13         Siskiyou     44592.0    405.9    1426.3
# 14        Calaveras     45085.0    321.6    1858.7
# 15         Tuolumne     54532.0    357.6    1969.5
# 16       San Benito     61513.0    239.0     767.3
# 17             Lake     64268.0    539.9    1910.7
# 18           Tehama     64643.0    396.0    2510.7
# 19             Yuba     77342.0    421.5    2384.2
# 20        Mendocino     88388.0    380.1    1419.9
# 21           Nevada     97820.0    243.3    1217.5
# 22           Sutter    102914.0    309.0    2377.7
# 23         Humboldt    133996.0    467.2    2929.9
# 24             Napa    139970.0    538.0    1544.6
# 25            Kings    152995.0    494.8    1611.8
# 26           Madera    158216.0    524.6    1702.1
# 27           Shasta    177891.0    350.2    1356.4
# 28         Imperial    188821.0    311.9    1840.9
# 29        El Dorado    190018.0    170.0    1346.7
# 30             Yolo    220896.0    288.4    3007.8
# 31            Butte    221521.0    462.3    2402.5
# 32            Marin    262240.0    196.8    2075.6
# 33       Santa Cruz    272501.0    405.9    2570.6
# 34  San Luis Obispo    278355.0    226.3    1839.0
# 35           Merced    280735.0    541.4    2457.1
# 36           Placer    395978.0    150.8    1550.1
# 37           Solano    438832.0    481.7    2999.1
# 38         Monterey    441304.0    324.7    1752.8
# 39    Santa Barbara    450839.0    339.1    1620.8
# 40           Tulare    476588.0    355.0    2229.4
# 41           Sonoma    496947.0    405.7    1360.3
# 42       Stanislaus    554018.0    524.9    2576.5
# 43      San Joaquin    765556.0    777.5    2796.5
# 44        San Mateo    774231.0    237.3    2101.7
# 45          Ventura    846050.0    216.3    1493.3
# 46    San Francisco    891021.0    683.7    5612.9
# 47             Kern    908405.0    612.8    3258.9
# 48           Fresno   1015195.0    466.6    2284.8
# 49     Contra Costa   1150621.0    359.6    2481.7
# 50       Sacramento   1541301.0    438.9    2350.2
# 51          Alameda   1664783.0    584.7    4008.4
# 52      Santa Clara   1954833.0    325.4    2435.3
# 53   San Bernardino   2168964.0    563.4    2186.1
# 54        Riverside   2422146.0    310.1    2394.0
# 55           Orange   3192987.0    212.9    1853.6
# 56        San Diego   3340312.0    341.6    1653.5
# 57      Los Angeles  10184378.0    553.9    2201.3
# 58              NaN         NaN      NaN       NaN

# %%
cleaned_crime = reset_crime_index.sort_values("Violent")
cleaned_crime
# Out:
#              County  Population  Violent  Property
# 1            Sierra      3210.0     31.2     965.7
# 36           Placer    395978.0    150.8    1550.1
# 29        El Dorado    190018.0    170.0    1346.7
# 32            Marin    262240.0    196.8    2075.6
# 55           Orange   3192987.0    212.9    1853.6
# 45          Ventura    846050.0    216.3    1493.3
# 34  San Luis Obispo    278355.0    226.3    1839.0
# 44        San Mateo    774231.0    237.3    2101.7
# 16       San Benito     61513.0    239.0     767.3
# 21           Nevada     97820.0    243.3    1217.5
# 8            Colusa     21990.0    263.8    1578.0
# 30             Yolo    220896.0    288.4    3007.8
# 12           Amador     37820.0    290.9    1771.5
# 22           Sutter    102914.0    309.0    2377.7
# 54        Riverside   2422146.0    310.1    2394.0
# 28         Imperial    188821.0    311.9    1840.9
# 10            Glenn     28695.0    317.1    1833.1
# 14        Calaveras     45085.0    321.6    1858.7
# 38         Monterey    441304.0    324.7    1752.8
# 52      Santa Clara   1954833.0    325.4    2435.3
# 39    Santa Barbara    450839.0    339.1    1620.8
# 56        San Diego   3340312.0    341.6    1653.5
# 27           Shasta    177891.0    350.2    1356.4
# 40           Tulare    476588.0    355.0    2229.4
# 15         Tuolumne     54532.0    357.6    1969.5
# 49     Contra Costa   1150621.0    359.6    2481.7
# 20        Mendocino     88388.0    380.1    1419.9
# 18           Tehama     64643.0    396.0    2510.7
# 9         Del Norte     27127.0    401.8    2963.8
# 41           Sonoma    496947.0    405.7    1360.3
# 33       Santa Cruz    272501.0    405.9    2570.6
# 13         Siskiyou     44592.0    405.9    1426.3
# 19             Yuba     77342.0    421.5    2384.2
# 5          Mariposa     18066.0    437.3    1007.4
# 50       Sacramento   1541301.0    438.9    2350.2
# 2             Modoc      9637.0    446.2     684.9
# 4           Trinity     13637.0    447.3    1737.9
# 31            Butte    221521.0    462.3    2402.5
# 48           Fresno   1015195.0    466.6    2284.8
# 23         Humboldt    133996.0    467.2    2929.9
# 37           Solano    438832.0    481.7    2999.1
# 25            Kings    152995.0    494.8    1611.8
# 3              Mono     13517.0    495.7    1383.4
# 7              Inyo     18572.0    506.1    2116.1
# 26           Madera    158216.0    524.6    1702.1
# 42       Stanislaus    554018.0    524.9    2576.5
# 24             Napa    139970.0    538.0    1544.6
# 17             Lake     64268.0    539.9    1910.7
# 35           Merced    280735.0    541.4    2457.1
# 57      Los Angeles  10184378.0    553.9    2201.3
# 53   San Bernardino   2168964.0    563.4    2186.1
# 51          Alameda   1664783.0    584.7    4008.4
# 47             Kern    908405.0    612.8    3258.9
# 46    San Francisco    891021.0    683.7    5612.9
# 6            Plumas     18242.0    701.7    1721.3
# 43      San Joaquin    765556.0    777.5    2796.5
# 11           Lassen     29173.0    939.2    1436.3
# 0            Alpine      1149.0   1131.4    2785.0
# 58              NaN         NaN      NaN       NaN

# %%
renamed_crime = cleaned_crime.rename(columns={"Violent": "Violent Crime Rate Per 100k", "Property": "Property Crime Rate Per 100k"})
renamed_crime.head()
# Out:
#        County  Population  Violent Crime Rate Per 100k  \
# 1      Sierra      3210.0                         31.2
# 36     Placer    395978.0                        150.8
# 29  El Dorado    190018.0                        170.0
# 32      Marin    262240.0                        196.8
# 55     Orange   3192987.0                        212.9
#
#     Property Crime Rate Per 100k
# 1                          965.7
# 36                        1550.1
# 29                        1346.7
# 32                        2075.6
# 55                        1853.6

# %%
resetting_index = renamed_crime.dropna (how = "any")
resetting_index
# Out:
#              County  Population  Violent Crime Rate Per 100k  \
# 1            Sierra      3210.0                         31.2
# 36           Placer    395978.0                        150.8
# 29        El Dorado    190018.0                        170.0
# 32            Marin    262240.0                        196.8
# 55           Orange   3192987.0                        212.9
# 45          Ventura    846050.0                        216.3
# 34  San Luis Obispo    278355.0                        226.3
# 44        San Mateo    774231.0                        237.3
# 16       San Benito     61513.0                        239.0
# 21           Nevada     97820.0                        243.3
# 8            Colusa     21990.0                        263.8
# 30             Yolo    220896.0                        288.4
# 12           Amador     37820.0                        290.9
# 22           Sutter    102914.0                        309.0
# 54        Riverside   2422146.0                        310.1
# 28         Imperial    188821.0                        311.9
# 10            Glenn     28695.0                        317.1
# 14        Calaveras     45085.0                        321.6
# 38         Monterey    441304.0                        324.7
# 52      Santa Clara   1954833.0                        325.4
# 39    Santa Barbara    450839.0                        339.1
# 56        San Diego   3340312.0                        341.6
# 27           Shasta    177891.0                        350.2
# 40           Tulare    476588.0                        355.0
# 15         Tuolumne     54532.0                        357.6
# 49     Contra Costa   1150621.0                        359.6
# 20        Mendocino     88388.0                        380.1
# 18           Tehama     64643.0                        396.0
# 9         Del Norte     27127.0                        401.8
# 41           Sonoma    496947.0                        405.7
# 33       Santa Cruz    272501.0                        405.9
# 13         Siskiyou     44592.0                        405.9
# 19             Yuba     77342.0                        421.5
# 5          Mariposa     18066.0                        437.3
# 50       Sacramento   1541301.0                        438.9
# 2             Modoc      9637.0                        446.2
# 4           Trinity     13637.0                        447.3
# 31            Butte    221521.0                        462.3
# 48           Fresno   1015195.0                        466.6
# 23         Humboldt    133996.0                        467.2
# 37           Solano    438832.0                        481.7
# 25            Kings    152995.0                        494.8
# 3              Mono     13517.0                        495.7
# 7              Inyo     18572.0                        506.1
# 26           Madera    158216.0                        524.6
# 42       Stanislaus    554018.0                        524.9
# 24             Napa    139970.0                        538.0
# 17             Lake     64268.0                        539.9
# 35           Merced    280735.0                        541.4
# 57      Los Angeles  10184378.0                        553.9
# 53   San Bernardino   2168964.0                        563.4
# 51          Alameda   1664783.0                        584.7
# 47             Kern    908405.0                        612.8
# 46    San Francisco    891021.0                        683.7
# 6            Plumas     18242.0                        701.7
# 43      San Joaquin    765556.0                        777.5
# 11           Lassen     29173.0                        939.2
# 0            Alpine      1149.0                       1131.4
#
#     Property Crime Rate Per 100k
# 1                          965.7
# 36                        1550.1
# 29                        1346.7
# 32                        2075.6
# 55                        1853.6
# 45                        1493.3
# 34                        1839.0
# 44                        2101.7
# 16                         767.3
# 21                        1217.5
# 8                         1578.0
# 30                        3007.8
# 12                        1771.5
# 22                        2377.7
# 54                        2394.0
# 28                        1840.9
# 10                        1833.1
# 14                        1858.7
# 38                        1752.8
# 52                        2435.3
# 39                        1620.8
# 56                        1653.5
# 27                        1356.4
# 40                        2229.4
# 15                        1969.5
# 49                        2481.7
# 20                        1419.9
# 18                        2510.7
# 9                         2963.8
# 41                        1360.3
# 33                        2570.6
# 13                        1426.3
# 19                        2384.2
# 5                         1007.4
# 50                        2350.2
# 2                          684.9
# 4                         1737.9
# 31                        2402.5
# 48                        2284.8
# 23                        2929.9
# 37                        2999.1
# 25                        1611.8
# 3                         1383.4
# 7                         2116.1
# 26                        1702.1
# 42                        2576.5
# 24                        1544.6
# 17                        1910.7
# 35                        2457.1
# 57                        2201.3
# 53                        2186.1
# 51                        4008.4
# 47                        3258.9
# 46                        5612.9
# 6                         1721.3
# 43                        2796.5
# 11                        1436.3
# 0                         2785.0

# %%
#exporting dataframe as a CSV
resetting_index.to_csv("../Resources/crime_rate_v1.csv", index = False, header = True)

# %% [markdown]
# # cleaning homelessess starts here

# %%
#reading in homelessness file
file2 = Path("../Resources/experiencing_homelessness_ethnicity_demographics.csv")
homeless = pd.read_csv(file2)
homeless.head()
# Out:
#    CALENDAR_YEAR LOCATION_ID                LOCATION            ETHNICITY  \
# 0           2017         All              California      Hispanic/Latinx
# 1           2017         All              California  Not Hispanic/Latinx
# 2           2017         All              California              Unknown
# 3           2017      CA-500  Santa Clara County CoC      Hispanic/Latinx
# 4           2017      CA-500  Santa Clara County CoC  Not Hispanic/Latinx
#
#   EXPERIENCING_HOMELESSNESS
# 0                     60962
# 1                    119153
# 2                      3791
# 3                      5034
# 4                      5074

# %%
#filtering for only the year 2019
filtered_homeless = homeless[homeless["CALENDAR_YEAR"] == 2019]
filtered_homeless.head()
# Out:
#      CALENDAR_YEAR LOCATION_ID                LOCATION            ETHNICITY  \
# 256           2019         All              California      Hispanic/Latinx
# 257           2019         All              California  Not Hispanic/Latinx
# 258           2019         All              California              Unknown
# 259           2019      CA-500  Santa Clara County CoC      Hispanic/Latinx
# 260           2019      CA-500  Santa Clara County CoC  Not Hispanic/Latinx
#
#     EXPERIENCING_HOMELESSNESS
# 256                     81432
# 257                    153135
# 258                      5027
# 259                      5972
# 260                      5938

# %%
#removing where ethnicity is unknown
df1 = filtered_homeless.loc[(filtered_homeless["ETHNICITY"] != "Unknown")]
df1.head()
# Out:
#      CALENDAR_YEAR LOCATION_ID                LOCATION            ETHNICITY  \
# 256           2019         All              California      Hispanic/Latinx
# 257           2019         All              California  Not Hispanic/Latinx
# 259           2019      CA-500  Santa Clara County CoC      Hispanic/Latinx
# 260           2019      CA-500  Santa Clara County CoC  Not Hispanic/Latinx
# 262           2019      CA-501       San Francisco CoC      Hispanic/Latinx
#
#     EXPERIENCING_HOMELESSNESS
# 256                     81432
# 257                    153135
# 259                      5972
# 260                      5938
# 262                      2351

# %%
#removing data from California overall
df2 = df1.loc[(df1["LOCATION"] != "California")]
df2.head()
# Out:
#      CALENDAR_YEAR LOCATION_ID                LOCATION            ETHNICITY  \
# 259           2019      CA-500  Santa Clara County CoC      Hispanic/Latinx
# 260           2019      CA-500  Santa Clara County CoC  Not Hispanic/Latinx
# 262           2019      CA-501       San Francisco CoC      Hispanic/Latinx
# 263           2019      CA-501       San Francisco CoC  Not Hispanic/Latinx
# 265           2019      CA-502      Alameda County CoC      Hispanic/Latinx
#
#     EXPERIENCING_HOMELESSNESS
# 259                      5972
# 260                      5938
# 262                      2351
# 263                      5429
# 265                      1416

# %%
#removing the null values in the experiencing_homelessness column marked with a *
df3 = df2.loc[(df2["EXPERIENCING_HOMELESSNESS"] != "*")]
df3.head()
# Out:
#      CALENDAR_YEAR LOCATION_ID                LOCATION            ETHNICITY  \
# 259           2019      CA-500  Santa Clara County CoC      Hispanic/Latinx
# 260           2019      CA-500  Santa Clara County CoC  Not Hispanic/Latinx
# 262           2019      CA-501       San Francisco CoC      Hispanic/Latinx
# 263           2019      CA-501       San Francisco CoC  Not Hispanic/Latinx
# 265           2019      CA-502      Alameda County CoC      Hispanic/Latinx
#
#     EXPERIENCING_HOMELESSNESS
# 259                      5972
# 260                      5938
# 262                      2351
# 263                      5429
# 265                      1416

# %%
#exporting to a CSV
#note more changes needed to be made on this exported CSV in excel (making a total column)
df3.to_csv("../Resources/homeless_v1.csv", index = False, header = True)

# %%
file_4 = Path("../Resources/homeless_v1.csv")
file_4_df = pd.read_csv(file_4)
file_4_df.head()
# Out:
#    CALENDAR_YEAR LOCATION_ID                LOCATION            ETHNICITY  \
# 0           2019      CA-500  Santa Clara County CoC      Hispanic/Latinx
# 1           2019      CA-500  Santa Clara County CoC  Not Hispanic/Latinx
# 2           2019      CA-501       San Francisco CoC      Hispanic/Latinx
# 3           2019      CA-501       San Francisco CoC  Not Hispanic/Latinx
# 4           2019      CA-502      Alameda County CoC      Hispanic/Latinx
#
#    EXPERIENCING_HOMELESSNESS
# 0                       5972
# 1                       5938
# 2                       2351
# 3                       5429
# 4                       1416

# %%
file_4_df.dtypes
# Out:
# CALENDAR_YEAR                 int64
# LOCATION_ID                  object
# LOCATION                     object
# ETHNICITY                    object
# EXPERIENCING_HOMELESSNESS     int64
# dtype: object

# %% [markdown]
# # cleaning unemployment starts here

# %%
file_5 = Path("../Resources/laborforceandunemployment_monthly_2024119.csv")
unemployment = pd.read_csv(file_5)
unemployment.head()
# Out:
#                             Area Name          Area Type  Year    Month  \
# 0                          California              State  1976  January
# 1                          California              State  1976  January
# 2                  Los Angeles County             County  1976  January
# 3                  Los Angeles County             County  1976  January
# 4  Los Angeles-Long Beach-Glendale MD  Metropolitan Area  1976  January
#
#   Date_Numeric Seasonally Adjusted(Y/N) Status  Labor Force  Employment  \
# 0       Jan-76                        N  Final      9672362     8668016
# 1       Jan-76                        Y  Final      9774280     8875685
# 2       Jan-76                        N  Final      3364151     3040058
# 3       Jan-76                        Y  Final      3381856     3081806
# 4       Jan-76                        N  Final      3364151     3040058
#
#    Unemployment  Unemployment Rate
# 0       1004346               10.4
# 1        898595                9.2
# 2        324093                9.6
# 3        300050                8.9
# 4        324093                9.6

# %%
unemployment2 = unemployment.loc[(unemployment["Area Type"] == "County")]
unemployment2.head()
# Out:
#              Area Name Area Type  Year     Month Date_Numeric  \
# 2   Los Angeles County    County  1976   January       Jan-76
# 3   Los Angeles County    County  1976   January       Jan-76
# 8   Los Angeles County    County  1976  February       Feb-76
# 9   Los Angeles County    County  1976  February       Feb-76
# 14  Los Angeles County    County  1976     March       Mar-76
#
#    Seasonally Adjusted(Y/N) Status  Labor Force  Employment  Unemployment  \
# 2                         N  Final      3364151     3040058        324093
# 3                         Y  Final      3381856     3081806        300050
# 8                         N  Final      3364401     3050306        314095
# 9                         Y  Final      3381218     3081497        299721
# 14                        N  Final      3361820     3069797        292023
#
#     Unemployment Rate
# 2                 9.6
# 3                 8.9
# 8                 9.3
# 9                 8.9
# 14                8.7

# %%
unemployment3 = unemployment2.loc[(unemployment2["Year"] == 2019)]
unemployment3
# Out:
#                Area Name Area Type  Year     Month Date_Numeric  \
# 133334    Alameda County    County  2019   January       Jan-19
# 133335     Alpine County    County  2019   January       Jan-19
# 133336     Amador County    County  2019   January       Jan-19
# 133337      Butte County    County  2019   January       Jan-19
# 133338  Calaveras County    County  2019   January       Jan-19
# ...                  ...       ...   ...       ...          ...
# 144641     Tulare County    County  2019  December       Dec-19
# 144642   Tuolumne County    County  2019  December       Dec-19
# 144643    Ventura County    County  2019  December       Dec-19
# 144644       Yolo County    County  2019  December       Dec-19
# 144645       Yuba County    County  2019  December       Dec-19
#
#        Seasonally Adjusted(Y/N) Status  Labor Force  Employment  Unemployment  \
# 133334                        N  Final       840900      811200         29800
# 133335                        N  Final          720         690            30
# 133336                        N  Final        14570       13830           740
# 133337                        N  Final        99200       92300          6900
# 133338                        N  Final        20900       19860          1040
# ...                         ...    ...          ...         ...           ...
# 144641                        N  Final       199800      180000         19800
# 144642                        N  Final        20600       19730           870
# 144643                        N  Final       423800      408800         14900
# 144644                        N  Final       107800      103300          4400
# 144645                        N  Final        30200       28400          1800
#
#         Unemployment Rate
# 133334                3.5
# 133335                4.3
# 133336                5.1
# 133337                6.9
# 133338                5.0
# ...                   ...
# 144641                9.9
# 144642                4.2
# 144643                3.5
# 144644                4.1
# 144645                5.9
#
# [708 rows x 11 columns]

# %%
unemployment4 = unemployment3.loc[(unemployment3["Month"] == "December")]
unemployment4.head()
# Out:
#                Area Name Area Type  Year     Month Date_Numeric  \
# 144587    Alameda County    County  2019  December       Dec-19
# 144588     Alpine County    County  2019  December       Dec-19
# 144589     Amador County    County  2019  December       Dec-19
# 144590      Butte County    County  2019  December       Dec-19
# 144591  Calaveras County    County  2019  December       Dec-19
#
#        Seasonally Adjusted(Y/N) Status  Labor Force  Employment  Unemployment  \
# 144587                        N  Final       845300      822800         22500
# 144588                        N  Final          520         500            30
# 144589                        N  Final        14670       14100           570
# 144590                        N  Final        97700       93200          4400
# 144591                        N  Final        21430       20660           770
#
#         Unemployment Rate
# 144587                2.7
# 144588                4.8
# 144589                3.9
# 144590                4.5
# 144591                3.6

# %%
unemployment5 = unemployment4.loc[(unemployment4["Seasonally Adjusted(Y/N)"] == "N")]
unemployment5.head()
# Out:
#                Area Name Area Type  Year     Month Date_Numeric  \
# 144587    Alameda County    County  2019  December       Dec-19
# 144588     Alpine County    County  2019  December       Dec-19
# 144589     Amador County    County  2019  December       Dec-19
# 144590      Butte County    County  2019  December       Dec-19
# 144591  Calaveras County    County  2019  December       Dec-19
#
#        Seasonally Adjusted(Y/N) Status  Labor Force  Employment  Unemployment  \
# 144587                        N  Final       845300      822800         22500
# 144588                        N  Final          520         500            30
# 144589                        N  Final        14670       14100           570
# 144590                        N  Final        97700       93200          4400
# 144591                        N  Final        21430       20660           770
#
#         Unemployment Rate
# 144587                2.7
# 144588                4.8
# 144589                3.9
# 144590                4.5
# 144591                3.6

# %%
sorted_unemployment = unemployment5.reset_index(drop = True)
sorted_unemployment.head()
# Out:
#           Area Name Area Type  Year     Month Date_Numeric  \
# 0    Alameda County    County  2019  December       Dec-19
# 1     Alpine County    County  2019  December       Dec-19
# 2     Amador County    County  2019  December       Dec-19
# 3      Butte County    County  2019  December       Dec-19
# 4  Calaveras County    County  2019  December       Dec-19
#
#   Seasonally Adjusted(Y/N) Status  Labor Force  Employment  Unemployment  \
# 0                        N  Final       845300      822800         22500
# 1                        N  Final          520         500            30
# 2                        N  Final        14670       14100           570
# 3                        N  Final        97700       93200          4400
# 4                        N  Final        21430       20660           770
#
#    Unemployment Rate
# 0                2.7
# 1                4.8
# 2                3.9
# 3                4.5
# 4                3.6

# %%
renamed_unemployment = sorted_unemployment.rename(columns={"Area Name": "County"})
renamed_unemployment.head()
# Out:
#              County Area Type  Year     Month Date_Numeric  \
# 0    Alameda County    County  2019  December       Dec-19
# 1     Alpine County    County  2019  December       Dec-19
# 2     Amador County    County  2019  December       Dec-19
# 3      Butte County    County  2019  December       Dec-19
# 4  Calaveras County    County  2019  December       Dec-19
#
#   Seasonally Adjusted(Y/N) Status  Labor Force  Employment  Unemployment  \
# 0                        N  Final       845300      822800         22500
# 1                        N  Final          520         500            30
# 2                        N  Final        14670       14100           570
# 3                        N  Final        97700       93200          4400
# 4                        N  Final        21430       20660           770
#
#    Unemployment Rate
# 0                2.7
# 1                4.8
# 2                3.9
# 3                4.5
# 4                3.6

# %%
minimized_unemployment = renamed_unemployment[["County", "Year", "Labor Force", "Employment", "Unemployment", "Unemployment Rate"]]
minimized_unemployment.head()
# Out:
#              County  Year  Labor Force  Employment  Unemployment  \
# 0    Alameda County  2019       845300      822800         22500
# 1     Alpine County  2019          520         500            30
# 2     Amador County  2019        14670       14100           570
# 3      Butte County  2019        97700       93200          4400
# 4  Calaveras County  2019        21430       20660           770
#
#    Unemployment Rate
# 0                2.7
# 1                4.8
# 2                3.9
# 3                4.5
# 4                3.6

# %%
minimized_unemployment.dtypes
# Out:
# County                object
# Year                   int64
# Labor Force            int64
# Employment             int64
# Unemployment           int64
# Unemployment Rate    float64
# dtype: object

# %%
sorted_unemployment = minimized_unemployment.sort_values("Unemployment Rate")
sorted_unemployment.head()
# Out:
#                   County  Year  Labor Force  Employment  Unemployment  \
# 40      San Mateo County  2019       460500      452000          8500
# 37  San Francisco County  2019       585100      573500         11700
# 20          Marin County  2019       138800      135900          2900
# 42    Santa Clara County  2019      1058000     1033900         24100
# 48         Sonoma County  2019       256600      250200          6400
#
#     Unemployment Rate
# 40                1.8
# 37                2.0
# 20                2.1
# 42                2.3
# 48                2.5

# %%
sorted_unemployment.reset_index(drop = True)
# Out:
#                     County  Year  Labor Force  Employment  Unemployment  \
# 0         San Mateo County  2019       460500      452000          8500
# 1     San Francisco County  2019       585100      573500         11700
# 2             Marin County  2019       138800      135900          2900
# 3       Santa Clara County  2019      1058000     1033900         24100
# 4            Sonoma County  2019       256600      250200          6400
# 5            Orange County  2019      1618800     1577800         41000
# 6           Alameda County  2019       845300      822800         22500
# 7   San Luis Obispo County  2019       137500      133800          3700
# 8      Contra Costa County  2019       562200      546500         15800
# 9            Placer County  2019       189100      183800          5300
# 10        San Diego County  2019      1586900     1540200         46800
# 11             Napa County  2019        70300       68200          2200
# 12           Nevada County  2019        48530       47040          1490
# 13             Inyo County  2019         8730        8450           280
# 14        El Dorado County  2019        92300       89300          3000
# 15         Humboldt County  2019        62200       60200          2000
# 16       Sacramento County  2019       712100      688000         24100
# 17             Mono County  2019         8770        8470           300
# 18   San Bernardino County  2019       985700      951900         33800
# 19          Ventura County  2019       423800      408800         14900
# 20           Solano County  2019       207600      200300          7300
# 21    Santa Barbara County  2019       222800      214700          8000
# 22        Calaveras County  2019        21430       20660           770
# 23        Riverside County  2019      1128300     1085800         42500
# 24           Amador County  2019        14670       14100           570
# 25        Mendocino County  2019        38280       36780          1500
# 26             Yolo County  2019       107800      103300          4400
# 27      Los Angeles County  2019      5216000     4995500        220500
# 28         Tuolumne County  2019        20600       19730           870
# 29           Shasta County  2019        73000       69700          3200
# 30            Butte County  2019        97700       93200          4400
# 31         Mariposa County  2019         7270        6950           330
# 32           Lassen County  2019         9280        8870           410
# 33           Alpine County  2019          520         500            30
# 34           Sierra County  2019         1350        1280            60
# 35       San Benito County  2019        32400       30800          1600
# 36       Santa Cruz County  2019       138400      131300          7100
# 37           Tehama County  2019        25390       24080          1310
# 38             Lake County  2019        28730       27180          1550
# 39          Trinity County  2019         4410        4160           240
# 40            Glenn County  2019        12780       12050           740
# 41      San Joaquin County  2019       328700      309500         19300
# 42       Stanislaus County  2019       241300      227100         14100
# 43             Yuba County  2019        30200       28400          1800
# 44        Del Norte County  2019         9460        8890           570
# 45         Siskiyou County  2019        16540       15430          1110
# 46           Madera County  2019        62900       58500          4300
# 47           Fresno County  2019       451000      418400         32600
# 48            Modoc County  2019         3040        2820           230
# 49             Kern County  2019       387400      358400         28900
# 50           Sutter County  2019        45100       41700          3500
# 51         Monterey County  2019       208800      192700         16100
# 52           Plumas County  2019         7470        6870           600
# 53            Kings County  2019        57600       52900          4700
# 54           Merced County  2019       114900      105400          9500
# 55           Tulare County  2019       199800      180000         19800
# 56           Colusa County  2019        10640        9080          1560
# 57         Imperial County  2019        74400       59100         15300
#
#     Unemployment Rate
# 0                 1.8
# 1                 2.0
# 2                 2.1
# 3                 2.3
# 4                 2.5
# 5                 2.5
# 6                 2.7
# 7                 2.7
# 8                 2.8
# 9                 2.8
# 10                2.9
# 11                3.1
# 12                3.1
# 13                3.2
# 14                3.2
# 15                3.2
# 16                3.4
# 17                3.4
# 18                3.4
# 19                3.5
# 20                3.5
# 21                3.6
# 22                3.6
# 23                3.8
# 24                3.9
# 25                3.9
# 26                4.1
# 27                4.2
# 28                4.2
# 29                4.4
# 30                4.5
# 31                4.5
# 32                4.5
# 33                4.8
# 34                4.8
# 35                5.0
# 36                5.1
# 37                5.2
# 38                5.4
# 39                5.5
# 40                5.8
# 41                5.9
# 42                5.9
# 43                5.9
# 44                6.0
# 45                6.7
# 46                6.9
# 47                7.2
# 48                7.4
# 49                7.5
# 50                7.7
# 51                7.7
# 52                8.1
# 53                8.1
# 54                8.3
# 55                9.9
# 56               14.6
# 57               20.5

# %%
renamed_unemployment2 = sorted_unemployment.rename(columns={"Employment": "Employment Count", "Unemployment": "Unemployment Count"})
renamed_unemployment2.head()
# Out:
#                   County  Year  Labor Force  Employment Count  \
# 40      San Mateo County  2019       460500            452000
# 37  San Francisco County  2019       585100            573500
# 20          Marin County  2019       138800            135900
# 42    Santa Clara County  2019      1058000           1033900
# 48         Sonoma County  2019       256600            250200
#
#     Unemployment Count  Unemployment Rate
# 40                8500                1.8
# 37               11700                2.0
# 20                2900                2.1
# 42               24100                2.3
# 48                6400                2.5

# %%
renamed_unemployment2.to_csv("../Resources/unemployment_v1.csv", index = False, header = True)
