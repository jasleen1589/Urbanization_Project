# %%
import pandas as pd
from pathlib import Path

# %%
homelessness = Path("experiencing_homelessness_ethnicity_demographics.csv")

# %%
labor_force = Path("laborforceandunemployment_monthly_2024119.csv")

# %%
crime_rate = Path("cleaner_crime_rate.csv")

# %%
homelessness_ca_df=pd.read_csv(homelessness)
homelessness_ca_df.head()
# Out:
#    CALENDAR_YEAR LOCATION_ID                LOCATION            ETHNICITY  \
# 0           2017         All              California      Hispanic/Latinx
# 1           2017         All              California  Not Hispanic/Latinx
# 2           2017         All              California              Unknown
# 3           2017      CA-500  Santa Clara County CoC      Hispanic/Latinx
# 4           2017      CA-500  Santa Clara County CoC  Not Hispanic/Latinx
#
#   EXPERIENCING_HOMELESSNESS
# 0                     60962
# 1                    119153
# 2                      3791
# 3                      5034
# 4                      5074

# %%
homelessness_ca_df[['CALENDAR_YEAR','LOCATION','EXPERIENCING_HOMELESSNESS']].head
# Out:
# <bound method NDFrame.head of      CALENDAR_YEAR                    LOCATION EXPERIENCING_HOMELESSNESS
# 0             2017                  California                     60962
# 1             2017                  California                    119153
# 2             2017                  California                      3791
# 3             2017      Santa Clara County CoC                      5034
# 4             2017      Santa Clara County CoC                      5074
# ..             ...                         ...                       ...
# 916           2023         Imperial County CoC                       182
# 917           2023         Imperial County CoC                        39
# 918           2023  San Luis Obispo County CoC                       881
# 919           2023  San Luis Obispo County CoC                      1499
# 920           2023  San Luis Obispo County CoC                       115
#
# [921 rows x 3 columns]>

# %%
filtered_homelessness_ca_df=homelessness_ca_df[homelessness_ca_df['CALENDAR_YEAR']>2018]
filtered_homelessness_ca_df
# Out:
#      CALENDAR_YEAR LOCATION_ID                    LOCATION  \
# 256           2019         All                  California
# 257           2019         All                  California
# 258           2019         All                  California
# 259           2019      CA-500      Santa Clara County CoC
# 260           2019      CA-500      Santa Clara County CoC
# ..             ...         ...                         ...
# 916           2023      CA-613         Imperial County CoC
# 917           2023      CA-613         Imperial County CoC
# 918           2023      CA-614  San Luis Obispo County CoC
# 919           2023      CA-614  San Luis Obispo County CoC
# 920           2023      CA-614  San Luis Obispo County CoC
#
#                ETHNICITY EXPERIENCING_HOMELESSNESS
# 256      Hispanic/Latinx                     81432
# 257  Not Hispanic/Latinx                    153135
# 258              Unknown                      5027
# ...

# %%
labor_force_ca_df=pd.read_csv(labor_force)
labor_force_ca_df.head()
# Out:
#                             Area Name          Area Type  Year    Month  \
# 0                          California              State  1976  January
# 1                          California              State  1976  January
# 2                  Los Angeles County             County  1976  January
# 3                  Los Angeles County             County  1976  January
# 4  Los Angeles-Long Beach-Glendale MD  Metropolitan Area  1976  January
#
#   Date_Numeric Seasonally Adjusted(Y/N) Status  Labor Force  Employment  \
# 0       Jan-76                        N  Final      9672362     8668016
# 1       Jan-76                        Y  Final      9774280     8875685
# 2       Jan-76                        N  Final      3364151     3040058
# 3       Jan-76                        Y  Final      3381856     3081806
# 4       Jan-76                        N  Final      3364151     3040058
#
#    Unemployment  Unemployment Rate
# 0       1004346               10.4
# ...

# %%
filtered_labor_force_ca_df=labor_force_ca_df[labor_force_ca_df['Year']>2018]
filtered_labor_force_ca_df
# Out:
#                 Area Name         Area Type  Year     Month Date_Numeric  \
# 133332         California             State  2019   January       Jan-19
# 133333         California             State  2019   January       Jan-19
# 133334     Alameda County            County  2019   January       Jan-19
# 133335      Alpine County            County  2019   January       Jan-19
# 133336      Amador County            County  2019   January       Jan-19
# ...                   ...               ...   ...       ...          ...
# 194704    Yountville town  Sub-County Place  2023  December       Dec-23
# 194705         Yreka city  Sub-County Place  2023  December       Dec-23
# 194706     Yuba City city  Sub-County Place  2023  December       Dec-23
# 194707       Yucaipa city  Sub-County Place  2023  December       Dec-23
# 194708  Yucca Valley town  Sub-County Place  2023  December       Dec-23
#
#        Seasonally Adjusted(Y/N)       Status  Labor Force  Employment  \
# ...

# %% [markdown]
# try converting the Date-Numeric to datetime but only in Month and year
# N and Y convert to Yes and No
# Check datatypes and do required changes as needed.

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure()

# Show the plot
plt.show()
plt.bar(filtered_labor_force_ca_df['Year'], filtered_labor_force_ca_df['Unemployment Rate'])
xlabel = 'Year'
ylabel = 'Unemployment Rate'
plt.show()

# %%
crime_rate_df=pd.read_csv(crime_rate)
crime_rate_df.head()
#Crimes Rates by County, 2019 presents the reported number of crimes per 100,000 residents.
# Out:
#       County Population   Violent  Murder   Rape  Robbery  Aggrevated assault  \
# 0    Alameda  1,664,783     584.7     5.8   42.2    295.3               241.5
# 1     Alpine      1,149  1,131.40     0.0  174.1      0.0               957.4
# 2     Amador     37,820     290.9     2.6   21.2     23.8               243.3
# 3      Butte    221,521     462.3     3.2   81.3     75.4               302.5
# 4  Calaveras     45,085     321.6     2.2   75.4     20.0               224.0
#
#    Property  Burglary  Vehicle theft Larceny theft
# 0  4,008.40     391.4          616.7      3,000.30
# 1  2,785.00  1,131.40          348.1      1,305.50
# 2  1,771.50     470.7           97.8      1,203.10
# 3  2,402.50     501.5          391.8      1,509.10
# 4  1,858.70     658.8          153.0      1,046.90

# %%
import json

# Create a dictionary representing a GeoJSON Feature Collection
geojson_data = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "geometry": {
                "type": "Point",
                "coordinates": [39.0996453445, -122.753183909]
            },
            "properties": {
                "name": "California"
            }
        }
    ]
}

# Write the GeoJSON data to a file
with open("California_Counties.geojson", "w") as geojson_file:
    json.dump(geojson_data, geojson_file)
